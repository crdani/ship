# %%
import pandas as pd

# %%
Route = pd.read_csv("Marine_routes.csv")

# %%
Route.dtypes
# Out:
# uuid                    object
# name                    object
# mmsi                     int64
# imo                      int64
# eni                    float64
# country_iso             object
# type                    object
# type_specific           object
# lat                    float64
# lon                    float64
# speed                  float64
# course                 float64
# heading                  int64
# departure               object
# destination             object
# last_position_epoch      int64
# last_position_UTC       object
# routes                  object
# id                       int64
# main                    object
# description             object
# icon                    object
# base                    object
# visibility               int64
# dt                       int64
# timezone                 int64
# name.1                  object
# cod                      int64
# coord.lon              float64
# coord.lat              float64
# main.temp              float64
# main.feels_like        float64
# main.temp_min          float64
# main.temp_max          float64
# main.pressure            int64
# main.humidity            int64
# main.sea_level           int64
# main.grnd_level          int64
# wind.speed             float64
# wind.deg                 int64
# wind.gust              float64
# clouds.all               int64
# sys.type                 int64
# sys.id                   int64
# sys.country             object
# sys.sunrise              int64
# sys.sunset               int64
# rain.1h                float64
# dtype: object

# %%
imo_options = Route["imo"].unique().tolist()
imo_options
# Out:
# [9454462, 9301201]

# %%
imo_grpby = Route.groupby("imo")
imo_grpby_1 = imo_grpby.get_group(9454462)
imo_grpby_1
imo_grpby_1_route = imo_grpby_1.groupby("routes")
imo_grpby_1_route_1 = imo_grpby_1_route.get_group("route01")
imo_grpby_1_route_1
# Out:
#                                      uuid   name       mmsi      imo  eni  \
# 0    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 1    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 2    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 3    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 4    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# ..                                    ...    ...        ...      ...  ...
# 158  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 159  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 160  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 161  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 162  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
#
#     country_iso   type  type_specific        lat       lon  ...  wind.speed  \
# 0            AG  Cargo  General Cargo  51.557835 -2.978727  ...        2.28
# 1            AG  Cargo  General Cargo  51.557822 -2.978743  ...        2.28
# 2            AG  Cargo  General Cargo  51.557815 -2.978757  ...        2.28
# 3            AG  Cargo  General Cargo  51.557807 -2.978765  ...        2.28
# 4            AG  Cargo  General Cargo  51.557805 -2.978768  ...        2.28
# ..          ...    ...            ...        ...       ...  ...         ...
# 158          AG  Cargo  General Cargo  43.322000 -1.920197  ...        1.54
# 159          AG  Cargo  General Cargo  43.321975 -1.920215  ...        1.54
# 160          AG  Cargo  General Cargo  43.321973 -1.920215  ...        1.54
# 161          AG  Cargo  General Cargo  43.321952 -1.920217  ...        1.54
# 162          AG  Cargo  General Cargo  43.321950 -1.920220  ...        1.54
#
#      wind.deg  wind.gust clouds.all sys.type   sys.id sys.country sys.sunrise  \
# 0         324        4.6         13        2  2001407          GB  1704529006
# 1         324        4.6         13        2  2001407          GB  1704529006
# 2         324        4.6         13        2  2001407          GB  1704529006
# 3         324        4.6         13        2  2001407          GB  1704529006
# 4         324        4.6         13        2  2001407          GB  1704529006
# ..        ...        ...        ...      ...      ...         ...         ...
# 158       140       11.5         75        2  2010406          ES  1704526797
# 159       140       11.5         75        2  2010406          ES  1704526797
# 160       140       11.5         75        2  2010406          ES  1704526797
# 161       140       11.4         75        2  2010406          ES  1704526797
# 162       140       11.4         75        2  2010406          ES  1704526797
#
#      sys.sunset rain.1h
# 0    1704557866     0.8
# 1    1704557866     0.8
# 2    1704557866     0.8
# 3    1704557866     0.8
# 4    1704557866     0.8
# ..          ...     ...
# 158  1704559567     1.8
# 159  1704559567     1.8
# 160  1704559567     1.8
# 161  1704559567     1.8
# 162  1704559567     1.8
#
# [163 rows x 48 columns]

# %%
trip_option = Route["routes"].unique()
route_group = Route.groupby("routes")
route01_trip = route_group.get_group('routes01')
route02_trip = route_group.get_group('routes02')
route03_trip = route_group.get_group('routes03')

# %%
imo_options = Route["imo"].unique().tolist()
imo_grpby = Route.groupby("imo")
imo_grpby_1 = imo_grpby.get_group(9454462)
imo_grpby_1_route = imo_grpby_1.groupby("routes")
imo_grpby_1_route_1 = imo_grpby_1_route.get_group("route01")
imo_grpby_1_route_2 = imo_grpby_1_route.get_group("route02")
imo_grpby_1_route_3 = imo_grpby_1_route.get_group("route03")

imo_grpby_2 = imo_grpby.get_group(9301201)
imo_grpby_2_route = imo_grpby_2.groupby("routes")
imo_grpby_2_route_1 = imo_grpby_2_route.get_group("route01")
imo_grpby_2_route_2 = imo_grpby_2_route.get_group("route02")
imo_grpby_2_route_3 = imo_grpby_2_route.get_group("route03")

# %%
imo_grpby_1_route_1
# Out:
#                                      uuid   name       mmsi      imo  eni  \
# 0    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 1    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 2    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 3    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 4    95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# ..                                    ...    ...        ...      ...  ...
# 158  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 159  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 160  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 161  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 162  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
#
#     country_iso   type  type_specific        lat       lon  ...  wind.speed  \
# 0            AG  Cargo  General Cargo  51.557835 -2.978727  ...        2.28
# 1            AG  Cargo  General Cargo  51.557822 -2.978743  ...        2.28
# 2            AG  Cargo  General Cargo  51.557815 -2.978757  ...        2.28
# 3            AG  Cargo  General Cargo  51.557807 -2.978765  ...        2.28
# 4            AG  Cargo  General Cargo  51.557805 -2.978768  ...        2.28
# ..          ...    ...            ...        ...       ...  ...         ...
# 158          AG  Cargo  General Cargo  43.322000 -1.920197  ...        1.54
# 159          AG  Cargo  General Cargo  43.321975 -1.920215  ...        1.54
# 160          AG  Cargo  General Cargo  43.321973 -1.920215  ...        1.54
# 161          AG  Cargo  General Cargo  43.321952 -1.920217  ...        1.54
# 162          AG  Cargo  General Cargo  43.321950 -1.920220  ...        1.54
#
#      wind.deg  wind.gust clouds.all sys.type   sys.id sys.country sys.sunrise  \
# 0         324        4.6         13        2  2001407          GB  1704529006
# 1         324        4.6         13        2  2001407          GB  1704529006
# 2         324        4.6         13        2  2001407          GB  1704529006
# 3         324        4.6         13        2  2001407          GB  1704529006
# 4         324        4.6         13        2  2001407          GB  1704529006
# ..        ...        ...        ...      ...      ...         ...         ...
# 158       140       11.5         75        2  2010406          ES  1704526797
# 159       140       11.5         75        2  2010406          ES  1704526797
# 160       140       11.5         75        2  2010406          ES  1704526797
# 161       140       11.4         75        2  2010406          ES  1704526797
# 162       140       11.4         75        2  2010406          ES  1704526797
#
#      sys.sunset rain.1h
# 0    1704557866     0.8
# 1    1704557866     0.8
# 2    1704557866     0.8
# 3    1704557866     0.8
# 4    1704557866     0.8
# ..          ...     ...
# 158  1704559567     1.8
# 159  1704559567     1.8
# 160  1704559567     1.8
# 161  1704559567     1.8
# 162  1704559567     1.8
#
# [163 rows x 48 columns]

# %%
imo_grpby_1_route_2
# Out:
#                                      uuid   name       mmsi      imo  eni  \
# 163  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 164  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 165  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 166  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 167  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 168  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 169  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 170  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 171  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 172  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 173  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 174  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 175  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 176  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 177  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 178  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 179  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 180  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 181  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 182  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 183  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 184  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 185  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 186  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 187  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 188  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 189  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 190  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 191  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 192  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 193  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 194  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 195  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 196  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 197  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 198  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 199  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 200  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 201  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 202  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 203  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 204  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 205  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 206  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 207  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 208  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 209  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 210  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 211  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 212  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 213  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
#
#     country_iso   type  type_specific        lat       lon  ...  wind.speed  \
# 163          AG  Cargo  General Cargo  43.321937 -1.920220  ...        1.54
# 164          AG  Cargo  General Cargo  43.321937 -1.920218  ...        1.54
# 165          AG  Cargo  General Cargo  43.321940 -1.920218  ...        1.54
# 166          AG  Cargo  General Cargo  43.321942 -1.920215  ...        1.54
# 167          AG  Cargo  General Cargo  43.321947 -1.920218  ...        1.54
# 168          AG  Cargo  General Cargo  43.358235 -1.980623  ...        1.54
# 169          AG  Cargo  General Cargo  43.384848 -2.082542  ...        8.95
# 170          AG  Cargo  General Cargo  43.407843 -2.180392  ...        9.88
# 171          AG  Cargo  General Cargo  43.430325 -2.280365  ...       10.52
# 172          AG  Cargo  General Cargo  43.455430 -2.380290  ...       10.69
# 173          AG  Cargo  General Cargo  43.480315 -2.476007  ...       11.06
# 174          AG  Cargo  General Cargo  43.504438 -2.572367  ...       11.53
# 175          AG  Cargo  General Cargo  43.524058 -2.654680  ...       11.52
# 176          AG  Cargo  General Cargo  43.533715 -2.776790  ...       11.47
# 177          AG  Cargo  General Cargo  43.527005 -2.899938  ...       11.30
# 178          AG  Cargo  General Cargo  43.499408 -2.972052  ...       11.16
# 179          AG  Cargo  General Cargo  43.453258 -3.040803  ...        2.57
# 180          AG  Cargo  General Cargo  43.427032 -3.106403  ...        8.67
# 181          AG  Cargo  General Cargo  43.369920 -3.061020  ...        4.63
# 182          AG  Cargo  General Cargo  43.358715 -3.062522  ...        4.63
# 183          AG  Cargo  General Cargo  43.358712 -3.062517  ...        4.63
# 184          AG  Cargo  General Cargo  43.358715 -3.062503  ...        4.63
# 185          AG  Cargo  General Cargo  43.358715 -3.062497  ...        4.63
# 186          AG  Cargo  General Cargo  43.358722 -3.062495  ...        4.63
# 187          AG  Cargo  General Cargo  43.358727 -3.062487  ...        4.63
# 188          AG  Cargo  General Cargo  43.358740 -3.062482  ...        4.63
# 189          AG  Cargo  General Cargo  43.358735 -3.062482  ...        4.63
# 190          AG  Cargo  General Cargo  43.358717 -3.062490  ...        4.63
# 191          AG  Cargo  General Cargo  43.358710 -3.062495  ...        4.63
# 192          AG  Cargo  General Cargo  43.358710 -3.062502  ...        4.63
# 193          AG  Cargo  General Cargo  43.358708 -3.062500  ...        4.63
# 194          AG  Cargo  General Cargo  43.358710 -3.062500  ...        4.63
# 195          AG  Cargo  General Cargo  43.358723 -3.062493  ...        4.63
# 196          AG  Cargo  General Cargo  43.358733 -3.062495  ...        4.63
# 197          AG  Cargo  General Cargo  43.358730 -3.062493  ...        4.63
# 198          AG  Cargo  General Cargo  43.358732 -3.062492  ...        4.63
# 199          AG  Cargo  General Cargo  43.358728 -3.062487  ...        4.63
# 200          AG  Cargo  General Cargo  43.358733 -3.062485  ...        4.63
# 201          AG  Cargo  General Cargo  43.358733 -3.062480  ...        4.63
# 202          AG  Cargo  General Cargo  43.358730 -3.062490  ...        4.63
# 203          AG  Cargo  General Cargo  43.358733 -3.062490  ...        4.63
# 204          AG  Cargo  General Cargo  43.358725 -3.062495  ...        4.63
# 205          AG  Cargo  General Cargo  43.358735 -3.062498  ...        4.63
# 206          AG  Cargo  General Cargo  43.358730 -3.062498  ...        4.63
# 207          AG  Cargo  General Cargo  43.358735 -3.062497  ...        4.63
# 208          AG  Cargo  General Cargo  43.358713 -3.062492  ...        4.63
# 209          AG  Cargo  General Cargo  43.358712 -3.062487  ...        4.63
# 210          AG  Cargo  General Cargo  43.358727 -3.062492  ...        4.63
# 211          AG  Cargo  General Cargo  43.358730 -3.062497  ...        4.63
# 212          AG  Cargo  General Cargo  43.358727 -3.062498  ...        4.63
# 213          AG  Cargo  General Cargo  43.358735 -3.062478  ...        4.63
#
#      wind.deg  wind.gust clouds.all sys.type   sys.id sys.country sys.sunrise  \
# 163       140       11.4         75        2  2010406          ES  1704526797
# 164       140       11.4         75        2  2010406          ES  1704526797
# 165       140       11.3         75        2  2010406          ES  1704526797
# 166       140       11.3         75        2  2010406          ES  1704526797
# 167       140       11.3         75        2  2010406          ES  1704526797
# 168       140       11.3         75        2  2042437          ES  1704526819
# 169       328       11.3         98        2  2042437          ES  1704526849
# 170       328       11.8         96        2  2042437          ES  1704526877
# 171       327       12.2         95        2  2042437          ES  1704526905
# 172       326       12.2         96        2  2042437          ES  1704526934
# 173       325       12.2         98        1     6395          ES  1704526962
# 174       325       12.4         91        1     6395          ES  1704526990
# 175       325       12.4         83        1     6395          ES  1704527014
# 176       325       12.4         73        1     6395          ES  1704527045
# 177       325       12.5         71        2  2038039          ES  1704527073
# 178       324       12.5         72        2  2038039          ES  1704527085
# 179       260       11.9         75        2  2038039          ES  1704527092
# 180       324       11.3         78        2  2038039          ES  1704527103
# 181       290       11.3         75        2  2038039          ES  1704527080
# 182       290       11.3         75        2  2038039          ES  1704527079
# 183       290       11.3         75        2  2038039          ES  1704527079
# 184       290       11.3         75        2  2038039          ES  1704527079
# 185       290       11.4         75        2  2038039          ES  1704527079
# 186       290       11.4         75        2  2038039          ES  1704527079
# 187       290       11.4         75        2  2038039          ES  1704527079
# 188       290       11.4         75        2  2038039          ES  1704527079
# 189       290       11.4         75        2  2038039          ES  1704527079
# 190       290       11.4         75        2  2038039          ES  1704527079
# 191       290       11.5         75        2  2038039          ES  1704527079
# 192       290       11.5         75        2  2038039          ES  1704527079
# 193       290       11.5         75        2  2038039          ES  1704527079
# 194       290       11.5         75        2  2038039          ES  1704527079
# 195       290       11.5         75        2  2038039          ES  1704527079
# 196       290       11.5         75        2  2038039          ES  1704527079
# 197       290       11.5         75        2  2038039          ES  1704527079
# 198       290       11.6         75        2  2038039          ES  1704527079
# 199       290       11.6         75        2  2038039          ES  1704527079
# 200       290       11.6         75        2  2038039          ES  1704527079
# 201       290       11.6         75        2  2038039          ES  1704527079
# 202       290       11.6         75        2  2038039          ES  1704527079
# 203       290       11.6         75        2  2038039          ES  1704527079
# 204       290       11.7         75        2  2038039          ES  1704527079
# 205       290       11.7         75        2  2038039          ES  1704527079
# 206       290       11.7         75        2  2038039          ES  1704527079
# 207       290       11.7         75        2  2038039          ES  1704527079
# 208       290       11.7         75        2  2038039          ES  1704527079
# 209       290       11.7         75        2  2038039          ES  1704527079
# 210       290       11.8         75        2  2038039          ES  1704527079
# 211       290       11.8         75        2  2038039          ES  1704527079
# 212       290       11.8         75        2  2038039          ES  1704527079
# 213       290       11.8         75        2  2038039          ES  1704527079
#
#      sys.sunset rain.1h
# 163  1704559567     1.8
# 164  1704559567     1.8
# 165  1704559567     1.8
# 166  1704559567     1.8
# 167  1704559567     1.8
# 168  1704559574     0.1
# 169  1704559593     0.2
# 170  1704559612     0.2
# 171  1704559632     0.3
# 172  1704559651     0.4
# 173  1704559669     0.4
# 174  1704559687     0.5
# 175  1704559703     0.6
# 176  1704559730     1.0
# 177  1704559761     1.0
# 178  1704559784     1.0
# 179  1704559810     0.9
# 180  1704559831     0.9
# 181  1704559831     0.9
# 182  1704559834     0.9
# 183  1704559834     0.9
# 184  1704559834     0.9
# 185  1704559834     0.9
# 186  1704559834     0.8
# 187  1704559834     0.8
# 188  1704559834     0.8
# 189  1704559834     0.8
# 190  1704559834     0.8
# 191  1704559834     0.8
# 192  1704559834     0.8
# 193  1704559834     0.7
# 194  1704559834     0.7
# 195  1704559834     0.7
# 196  1704559834     0.7
# 197  1704559834     0.7
# 198  1704559834     0.7
# 199  1704559834     0.7
# 200  1704559834     0.6
# 201  1704559834     0.6
# 202  1704559834     0.6
# 203  1704559834     0.6
# 204  1704559834     0.6
# 205  1704559834     0.6
# 206  1704559834     0.6
# 207  1704559834     0.5
# 208  1704559834     0.5
# 209  1704559834     0.5
# 210  1704559834     0.5
# 211  1704559834     0.5
# 212  1704559834     0.5
# 213  1704559834     0.5
#
# [51 rows x 48 columns]

# %%
imo_grpby_1_route_3
# Out:
#                                      uuid   name       mmsi      imo  eni  \
# 214  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 215  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 216  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 217  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 218  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# ..                                    ...    ...        ...      ...  ...
# 505  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 506  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 507  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 508  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
# 509  95badbc2-0ed6-2a04-e2a7-effaac627905  ELISE  305170000  9454462  NaN
#
#     country_iso   type  type_specific        lat       lon  ...  wind.speed  \
# 214          AG  Cargo  General Cargo  43.358630 -3.061790  ...        4.63
# 215          AG  Cargo  General Cargo  43.358583 -3.061493  ...        4.63
# 216          AG  Cargo  General Cargo  43.358592 -3.061488  ...        4.63
# 217          AG  Cargo  General Cargo  43.358593 -3.061490  ...        4.63
# 218          AG  Cargo  General Cargo  43.358598 -3.061485  ...        4.63
# ..          ...    ...            ...        ...       ...  ...         ...
# 505          AG  Cargo  General Cargo  52.473037  4.608070  ...        7.18
# 506          AG  Cargo  General Cargo  52.473040  4.608072  ...        7.18
# 507          AG  Cargo  General Cargo  52.473038  4.608075  ...        7.18
# 508          AG  Cargo  General Cargo  52.473035  4.608070  ...        7.18
# 509          AG  Cargo  General Cargo  52.473032  4.608072  ...        7.18
#
#      wind.deg  wind.gust clouds.all sys.type   sys.id sys.country sys.sunrise  \
# 214       290       11.8         75        2  2038039          ES  1704527079
# 215       290       11.8         75        2  2038039          ES  1704527079
# 216       290       11.9         75        2  2038039          ES  1704527079
# 217       290       11.9         75        2  2038039          ES  1704527079
# 218       290       11.9         75        2  2038039          ES  1704527079
# ..        ...        ...        ...      ...      ...         ...         ...
# 505        19        9.4        100        2  2009418          NL  1704527458
# 506        19        9.4        100        2  2009418          NL  1704527458
# 507        19        9.4        100        2  2009418          NL  1704527458
# 508        19        9.4        100        2  2009418          NL  1704527458
# 509        19        9.4        100        2  2009418          NL  1704527458
#
#      sys.sunset rain.1h
# 214  1704559834    0.40
# 215  1704559834    0.40
# 216  1704559834    0.40
# 217  1704559834    0.40
# 218  1704559834    0.40
# ..          ...     ...
# 505  1704555773    0.70
# 506  1704555773    0.70
# 507  1704555773    0.70
# 508  1704555773    0.70
# 509  1704555773    0.25
#
# [296 rows x 48 columns]

# %%
imo_grpby_2_route_1
# Out:
#                                      uuid       name       mmsi      imo  eni  \
# 510  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 511  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 512  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 513  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 514  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# ..                                    ...        ...        ...      ...  ...
# 846  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 847  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 848  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 849  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
# 850  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201  NaN
#
#     country_iso   type           type_specific        lat       lon  ...  \
# 510          LR  Cargo  Cargo or Containership  41.194733 -8.683200  ...
# 511          LR  Cargo  Cargo or Containership  41.194707 -8.683185  ...
# 512          LR  Cargo  Cargo or Containership  41.194715 -8.683183  ...
# 513          LR  Cargo  Cargo or Containership  41.194717 -8.683195  ...
# 514          LR  Cargo  Cargo or Containership  41.194722 -8.683257  ...
# ..          ...    ...                     ...        ...       ...  ...
# 846          LR  Cargo  Cargo or Containership  51.957298  3.995948  ...
# 847          LR  Cargo  Cargo or Containership  51.957260  3.995960  ...
# 848          LR  Cargo  Cargo or Containership  51.957258  3.995948  ...
# 849          LR  Cargo  Cargo or Containership  51.957332  3.995967  ...
# 850          LR  Cargo  Cargo or Containership  51.957350  3.995918  ...
#
#      wind.speed  wind.deg  wind.gust clouds.all sys.type   sys.id sys.country  \
# 510        3.09       120        1.0          0        1     6900          PT
# 511        3.09       120        1.3          0        1     6900          PT
# 512        3.09       120        1.5          0        1     6900          PT
# 513        3.09       120        1.6          0        1     6900          PT
# 514        3.09       120        1.5          0        1     6900          PT
# ..          ...       ...        ...        ...      ...      ...         ...
# 846        9.49        60       11.0         29        2  2010451          NL
# 847        9.49        60       11.0         29        2  2010451          NL
# 848        9.49        60       11.0         29        2  2010451          NL
# 849        9.49        60       11.0         29        2  2010451          NL
# 850        9.49        60       11.0         29        2  2010451          NL
#
#     sys.sunrise  sys.sunset rain.1h
# 510  1704614411  1704648052    0.25
# 511  1704614411  1704648052    0.25
# 512  1704614411  1704648052    0.25
# 513  1704614411  1704648052    0.25
# 514  1704614411  1704648052    0.25
# ..          ...         ...     ...
# 846  1704613826  1704642549    0.37
# 847  1704613826  1704642549    0.37
# 848  1704613826  1704642549    0.37
# 849  1704613826  1704642549    0.37
# 850  1704613826  1704642549    0.37
#
# [341 rows x 48 columns]

# %%
imo_grpby_2_route_2
# Out:
#                                       uuid       name       mmsi      imo  \
# 851   1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 852   1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 853   1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 854   1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 855   1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# ...                                    ...        ...        ...      ...
# 1027  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1028  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1029  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1030  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1031  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
#
#       eni country_iso   type           type_specific        lat       lon  \
# 851   NaN          LR  Cargo  Cargo or Containership  51.957285  3.995990
# 852   NaN          LR  Cargo  Cargo or Containership  51.957292  3.996033
# 853   NaN          LR  Cargo  Cargo or Containership  51.957320  3.995905
# 854   NaN          LR  Cargo  Cargo or Containership  51.975952  4.008537
# 855   NaN          LR  Cargo  Cargo or Containership  51.992620  4.044502
# ...   ...         ...    ...                     ...        ...       ...
# 1027  NaN          LR  Cargo  Cargo or Containership  38.725688 -9.106735
# 1028  NaN          LR  Cargo  Cargo or Containership  38.725715 -9.106745
# 1029  NaN          LR  Cargo  Cargo or Containership  38.725687 -9.106763
# 1030  NaN          LR  Cargo  Cargo or Containership  38.725713 -9.106743
# 1031  NaN          LR  Cargo  Cargo or Containership  38.725752 -9.106747
#
#       ...  wind.speed  wind.deg  wind.gust clouds.all sys.type   sys.id  \
# 851   ...        9.49        60       11.0         29        2  2010451
# 852   ...        9.49        60       11.0         29        2  2010451
# 853   ...        9.49        60       11.0         29        2  2010451
# 854   ...        9.46        60       11.0         23        2  2010451
# 855   ...        3.58        49        6.7         19        2  2010451
# ...   ...         ...       ...        ...        ...      ...      ...
# 1027  ...        3.13       135        3.1         20        1     6901
# 1028  ...        3.13       135        3.1         20        1     6901
# 1029  ...        3.13       135        3.1         20        1     6901
# 1030  ...        3.13       135        3.1         20        1     6901
# 1031  ...        3.13       135        3.1         20        1     6901
#
#      sys.country sys.sunrise  sys.sunset rain.1h
# 851           NL  1704613826  1704642549    0.37
# 852           NL  1704613826  1704642549    0.38
# 853           NL  1704613826  1704642549    0.38
# 854           NL  1704613829  1704642541    0.38
# 855           NL  1704613825  1704642527    0.38
# ...          ...         ...         ...     ...
# 1027          PT  1704614083  1704648584    0.27
# 1028          PT  1704614083  1704648584    0.27
# 1029          PT  1704614083  1704648584    0.27
# 1030          PT  1704614083  1704648584    0.27
# 1031          PT  1704614083  1704648584    0.27
#
# [181 rows x 48 columns]

# %%
imo_grpby_2_route_3
# Out:
#                                       uuid       name       mmsi      imo  \
# 1032  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1033  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1034  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1035  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1036  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# ...                                    ...        ...        ...      ...
# 1111  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1112  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1113  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1114  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
# 1115  1183fa82-b8d4-e643-f7f1-07b46733a543  MASTERY D  636092240  9301201
#
#       eni country_iso   type           type_specific        lat       lon  \
# 1032  NaN          LR  Cargo  Cargo or Containership  38.725728 -9.106845
# 1033  NaN          LR  Cargo  Cargo or Containership  38.725668 -9.106718
# 1034  NaN          LR  Cargo  Cargo or Containership  38.692060 -9.176375
# 1035  NaN          LR  Cargo  Cargo or Containership  38.687277 -9.283895
# 1036  NaN          LR  Cargo  Cargo or Containership  38.605437 -9.398557
# ...   ...         ...    ...                     ...        ...       ...
# 1111  NaN          LR  Cargo  Cargo or Containership  41.194765 -8.683092
# 1112  NaN          LR  Cargo  Cargo or Containership  41.194628 -8.683082
# 1113  NaN          LR  Cargo  Cargo or Containership  41.194760 -8.683097
# 1114  NaN          LR  Cargo  Cargo or Containership  41.194757 -8.683122
# 1115  NaN          LR  Cargo  Cargo or Containership  41.194678 -8.682980
#
#       ...  wind.speed  wind.deg  wind.gust clouds.all sys.type   sys.id  \
# 1032  ...        3.13       135        3.1         20        1     6901
# 1033  ...        3.13       135        3.1         20        1     6901
# 1034  ...        3.13       135        3.1         20        2  2039356
# 1035  ...        2.68       140        3.6          0        2  2002944
# 1036  ...        2.68       140        3.6          0        2  2002944
# ...   ...         ...       ...        ...        ...      ...      ...
# 1111  ...        3.09       120        1.0          0        1     6900
# 1112  ...        3.09       120        1.0          0        1     6900
# 1113  ...        3.09       120        1.0          0        1     6900
# 1114  ...        3.09       120        1.0          0        1     6900
# 1115  ...        3.09       120        1.0          0        1     6900
#
#      sys.country sys.sunrise  sys.sunset rain.1h
# 1032          PT  1704614083  1704648584    0.27
# 1033          PT  1704614083  1704648584    0.27
# 1034          PT  1704614094  1704648606    0.27
# 1035          PT  1704614119  1704648633    0.27
# 1036          PT  1704614133  1704648674    0.27
# ...          ...         ...         ...     ...
# 1111          PT  1704614411  1704648052    0.27
# 1112          PT  1704614411  1704648052    0.27
# 1113          PT  1704614411  1704648052    0.27
# 1114          PT  1704614411  1704648052    0.27
# 1115          PT  1704614411  1704648052    0.27
#
# [84 rows x 48 columns]

# %%
grouped_data = Route.groupby(["imo", "routes"])

# %%
from PIL import Image
import streamlit as st
import pandas as pd

Route = pd.read_csv("Marine_routes.csv")

trip_option = Route["routes"].unique()
imo_options = Route["imo"].unique().tolist()
grouped_data = Route.groupby(['imo', 'routes'])

group_9454462_r1 = grouped_data.get_group((9454462, 'route01'))
group_9454462_r2 = grouped_data.get_group((9454462, 'route02'))
group_9454462_r3 = grouped_data.get_group((9454462, 'route03'))
group_9301201_r1 = grouped_data.get_group((9301201, 'route01'))
group_9301201_r2 = grouped_data.get_group((9301201, 'route02'))
group_9301201_r3 = grouped_data.get_group((9301201, 'route03'))

st.set_page_config(page_title="Vessels", 
                   page_icon=":ship:", 
                   layout="wide",
                   initial_sidebar_state="expanded")

st.sidebar.header("Vessel Dashboard")

Selected_IMO = st.sidebar.selectbox("Select IMO", imo_options, 0)
Routes = st.sidebar.selectbox("Select Route", trip_option, 0)

st.title("Vessel Route Dashboard")
st.header("This dashboard visualizes the vessel route with detailed information at each point.")

if Routes == 'routes01' and Selected_IMO == 9454462:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9454462_r1['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9454462_r1['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9454462_r1['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9454462_r1['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9454462_r1['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9454462_r1['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9454462_r1['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9454462_r1['country_iso'].iloc[0]}")
    
    file_path = '(9454462)route01.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9454462)kpi(R1).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9454462)weather_frequency(R1).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9454462)speed_frequency(R1).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9454462)speed(R1).png')
        st.image(image_4, caption='speed')

# %%
from PIL import Image
import streamlit as st
import pandas as pd

Route = pd.read_csv("Marine_routes.csv")

trip_option = Route["routes"].unique()
imo_options = Route["imo"].unique().tolist()
grouped_data = Route.groupby(['imo', 'routes'])

group_9454462_r1 = grouped_data.get_group((9454462, 'route01'))
group_9454462_r2 = grouped_data.get_group((9454462, 'route02'))
group_9454462_r3 = grouped_data.get_group((9454462, 'route03'))
group_9301201_r1 = grouped_data.get_group((9301201, 'route01'))
group_9301201_r2 = grouped_data.get_group((9301201, 'route02'))
group_9301201_r3 = grouped_data.get_group((9301201, 'route03'))

st.set_page_config(page_title="Vessels", 
                   page_icon=":ship:", 
                   layout="wide",
                   initial_sidebar_state="expanded")

st.sidebar.header("Vessel Dashboard")

Selected_IMO = st.sidebar.selectbox("Select IMO", imo_options, 0)
Routes = st.sidebar.selectbox("Select Route", trip_option, 0)

st.title("Vessel Route Dashboard")
st.header("This dashboard visualizes the vessel route with detailed information at each point.")

if Routes == 'routes01' and Selected_IMO == 9454462:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9454462_r1['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9454462_r1['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9454462_r1['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9454462_r1['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9454462_r1['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9454462_r1['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9454462_r1['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9454462_r1['country_iso'].iloc[0]}")
    
    file_path = '(9454462)route01.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9454462)kpi(R1).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9454462)weather_frequency(R1).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9454462)speed_frequency(R1).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9454462)speed(R1).png')
        st.image(image_4, caption='speed')

elif Routes == 'routes02' and Selected_IMO == 9454462:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9454462_r2['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9454462_r2['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9454462_r2['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9454462_r2['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9454462_r2['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9454462_r2['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9454462_r2['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9454462_r2['country_iso'].iloc[0]}")

    file_path = '(9454462)route02.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9454462)kpi(R2).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9454462)weather_frequency(R2).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9454462)speed_frequency(R2).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9454462)speed(R2).png')
        st.image(image_4, caption='speed')

elif Routes == 'routes03' and Selected_IMO == 9454462:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9454462_r3['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9454462_r3['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9454462_r3['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9454462_r3['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9454462_r3['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9454462_r3['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9454462_r3['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9454462_r3['country_iso'].iloc[0]}")

    file_path = '(9454462)route03.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9454462)kpi(R3).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9454462)weather_frequency(R3).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9454462)speed_frequency(R3).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9454462)speed(R3).png')
        st.image(image_4, caption='speed')

elif Routes == 'routes01' and Selected_IMO == 9301201:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9301201_r1['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9301201_r1['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9301201_r1['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9301201_r1['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9301201_r1['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9301201_r1['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9301201_r1['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9301201_r1['country_iso'].iloc[0]}")
    
    file_path = '(9301201)route01.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9301201)kpi(R1).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9301201)weather_frequency(R1).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9301201)speed_frequency(R1).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9301201)speed(R1).png')
        st.image(image_4, caption='speed')

elif Routes == 'routes02' and Selected_IMO == 9301201:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9301201_r2['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9301201_r2['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9301201_r2['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9301201_r2['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9301201_r2['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9301201_r2['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9301201_r2['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9301201_r2['country_iso'].iloc[0]}")

    file_path = '(9301201)route02.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9301201)kpi(R2).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9301201)weather_frequency(R2).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9301201)speed_frequency(R2).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9301201)speed(R2).png')
        st.image(image_4, caption='speed')

elif Routes == 'routes03' and Selected_IMO == 9301201:
    st.subheader("Vessel Information")
    col1, col2, col3, col4 = st.columns(4)
    col1.info(f"**Vessel Name:** {group_9301201_r3['name'].iloc[0]}")
    col2.info(f"**Vessel Type:** {group_9301201_r3['type_specific'].iloc[0]}")
    col3.info(f"**Average Vessel Speed:** {round(group_9301201_r3['speed'].mean(), 2)}")
    
    col4.info(f"**Average Wind Pressure:** {round(group_9301201_r3['main.pressure'].mean(), 2)}")
    col5, col6, col7, col8 = st.columns(4)
    col5.info(f"**Average Wind Speed:** {round(group_9301201_r3['wind.speed'].mean(), 2)}")
    col6.info(f"**Vessel IMOs:** {group_9301201_r3['imo'].iloc[0]}")
    
    col7.info(f"**Vessel MMSIs:** {group_9301201_r3['mmsi'].iloc[0]}")
    col8.info(f"**Country Code:** {group_9301201_r3['country_iso'].iloc[0]}")

    file_path = '(9301201)route03.html'
    with open(file_path, 'r') as f:
        html_data = f.read()

    st.subheader("Vessel Locator Map")
    st.components.v1.html(html_data, height=700)

    st.subheader("Plots")
    
    col1, col2 = st.columns(2)

# Load and display images in columns
    with col1:
        image_1 = Image.open('(9301201)kpi(R3).png')
        st.image(image_1, caption='kpi')

        image_2 = Image.open('(9301201)weather_frequency(R3).png')
        st.image(image_2, caption='Weather Frequency')

    with col2:
        image_3 = Image.open('(9301201)speed_frequency(R3).png')
        st.image(image_3, caption='Speed Frequency')

        image_4 = Image.open('(9301201)speed(R3).png')
        st.image(image_4, caption='speed')

else:
    st.write("Data Not Available")
